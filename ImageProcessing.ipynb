# %% [markdown]
# <a href="https://colab.research.google.com/github/sowbarnikachennai/sowbarnikachennai/blob/AIML/ImageProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Success Sowbarnika")
# Out:
# Success Sowbarnika

# %%
# !cat /proc/cpuinfo

# %%
from google.colab import drive
drive.mount('Reiki_to_Mother_Earth.jpg')

# %% [markdown]
# # Image Proccessing

# %%
from IPython.display import Image
Image(filename = "Reiki_to_Mother_Earth.jpg", width=400, height=400)

# %%
#ImageProccessing
import cv2
import numpy as np
import random
import imutils

# %%
image= cv2.imread("Reiki_to_Mother_Earth.jpg")

cv2.imshow("image",image)
cv2.imwrite("Testing.jpg",image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c77d349b8f31> in <module>()
#       1 image= cv2.imread("Reiki_to_Mother_Earth.jpg")
#       2
# ----> 3 cv2_imshow("image",image)
#       4 cv2.imwrite("Testing.jpg",image)
#
# NameError: name 'cv2_imshow' is not defined

# %%
can = np.zeros((1000,1000,3),dtype="uint8")*255
cv2.imshow("canvas",can)

# %%
can = np.ones((1000,1000,3),dtype="uint8")*255
green = (0,255,0)
cv2.line(can,(0,0),(500,500),green, 3)

red = (0,100,255)
cv2.rectangle(can,(100,100),(300,300),red, -1)

cv2.imshow("canvas",can)

# %%
#Create Circles
for i in range(0,25):
    radius=np.random.randint(5,100)
    color=np.random.randint(0,high=256,size=(3,)).tolist()
    point=np.random.randint(0,800,size=(2,))
    cv2.circle(can,list(point),radius,color,-1)
 
cv2.putText(can,"My Happy Circles",(100,100),cv2.FONT_HERSHEY_SIMPLEX,1.5,(100,0,50),5)
cv2.imshow("MyCircles",can)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5968a264203f> in <module>()
#       4     color=np.random.randint(0,high=256,size=(3,)).tolist()
#       5     point=np.random.randint(0,800,size=(2,))
# ----> 6     cv2.circle(can,list(point),radius,color,-1)
#       7
#       8 cv2.putText(can,"My Happy Circles",(100,100),cv2.FONT_HERSHEY_SIMPLEX,1.5,(100,0,50),5)
#
# NameError: name 'can' is not defined

# %%
#Translate

image= cv2.imread("E:\Anusha\Reiki_to_Mother_Earth.jpg")
shift=
cv2.imshow("image",image)
