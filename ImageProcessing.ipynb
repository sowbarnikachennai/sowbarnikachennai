# %% [markdown]
# <a href="https://colab.research.google.com/github/sowbarnikachennai/sowbarnikachennai/blob/AIML/ImageProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Success Sowbarnika")
# Out:
# Success Sowbarnika

# %%
# !cat /proc/cpuinfo

# %%
from google.colab import drive
drive.mount('Reiki_to_Mother_Earth.jpg')

# %% [markdown]
# # Image Proccessing

# %%
from IPython.display import Image
Image(filename = "Reiki_to_Mother_Earth.jpg", width=400, height=400)

# %%
# !pip install opencv-python

# %%
#ImageProccessing
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import random
import imutils

# %%
image= cv2.imread("Reiki_to_Mother_Earth.jpg")

cv2_imshow(image)
cv2.imwrite("Testing.jpg",image)

# %%
can = np.zeros((1000,1000,3),dtype="uint8")*255
cv2_imshow(can)

# %%
can = np.ones((1000,1000,3),dtype="uint8")*255
green = (0,255,0)
cv2.line(can,(0,0),(500,500),green, 3)

red = (0,100,255)
cv2.rectangle(can,(100,100),(300,300),red, -1)

cv2_imshow(can)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000 at 0x7F5060BD63D0>

# %%
#Create Circles
for i in range(0,25):
    radius=np.random.randint(5,100)
    color=np.random.randint(0,high=256,size=(3,)).tolist()
    point=np.random.randint(0,800,size=(2,))
    cv2.circle(can,tuple(point),radius,color,-1)
 
cv2.putText(can,"My Happy Circles",(100,100),cv2.FONT_HERSHEY_SIMPLEX,1.5,(100,0,50),5)
cv2_imshow(can)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000 at 0x7F5060BCB690>

# %%
#Translate

image= cv2.imread("Reiki_to_Mother_Earth.jpg")
cv2_imshow(image)

# %% [markdown]
# # **Translate**

# %%
shift= imutils.translate(image,100,400)
cv2_imshow(shift)

# %% [markdown]
# # **Rotate**

# %%
rotated= imutils.rotate(image,270)
cv2_imshow(rotated)

# %% [markdown]
# # **Crop**

# %%
crop= image[100:400,400:800]
cv2_imshow(crop)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7F5060BF46D0>
